# %%
import pandas as pd

# %%
chicago = pd.read_csv("chicago.csv")
chicago["Department"] = chicago["Department"].astype("category")
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32063 entries, 0 to 32062
# Data columns (total 4 columns):
# Name                      32062 non-null object
# Position Title            32062 non-null object
# Department                32062 non-null category
# Employee Annual Salary    32062 non-null object
# dtypes: category(1), object(3)
# memory usage: 783.1+ KB

# %%
chicago["Department"].nunique()
# Out:
# 35

# %%
chicago["Department"].count()
# Out:
# 32062

# %%
chicago["Department"] = chicago["Department"].astype("category")
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %% [markdown]
# ###  Common String Method - .lower(), .upper(), .title() and .len()

# %%
chicago = pd.read_csv("chicago.csv")
chicago["Department"] = chicago["Department"].astype("category")
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
chicago['Name'].str.title()
chicago["Position Title"] = chicago["Position Title"].str.title()
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          Water Rate Taker       WATER MGMNT
# 1    AARON,  JEFFERY M            Police Officer            POLICE
# 2       AARON,  KARINA            Police Officer            POLICE
# 3  AARON,  KIMBERLEI R  Chief Contract Expediter  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         Civil Engineer Iv       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
chicago["Position Title"].str.len()
# Out:
# 0        16.0
# 1        14.0
# 2        14.0
# 3        24.0
# 4        17.0
# 5        20.0
# 6        21.0
# 7        27.0
# 8        26.0
# 9        19.0
# 10       17.0
# 11       14.0
# 12       18.0
# 13        9.0
# 14       22.0
# 15       14.0
# 16       14.0
# 17       45.0
# 18       14.0
# 19       21.0
# 20       25.0
# 21       15.0
# 22       10.0
# 23       14.0
# 24       39.0
# 25       17.0
# 26       21.0
# 27       18.0
# 28       14.0
# 29        9.0
#          ...
# 32033    14.0
# 32034    14.0
# 32035    14.0
# 32036    21.0
# 32037    15.0
# 32038    20.0
# 32039    14.0
# 32040    14.0
# 32041    14.0
# 32042    30.0
# 32043    18.0
# 32044    14.0
# 32045    19.0
# 32046    33.0
# 32047    14.0
# 32048    15.0
# 32049    14.0
# 32050    23.0
# 32051    27.0
# 32052    14.0
# 32053    15.0
# 32054    14.0
# 32055    14.0
# 32056    22.0
# 32057    30.0
# 32058    14.0
# 32059    14.0
# 32060    14.0
# 32061    23.0
# 32062     NaN
# ...

# %%
chicago["Position Title"].count()
# Out:
# 32062

# %%
chicago.apply(lambda col: col.count())
# Out:
# Name                      32062
# Position Title            32062
# Department                32062
# Employee Annual Salary    32062
# dtype: int64

# %%
chicago = pd.read_csv("chicago.csv")
chicago["Department"] = chicago["Department"].astype("category")
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
"h".upper()
# Out:
# 'H'

# %%
'A'.lower()
# Out:
# 'a'

# %%
'hello pragya pradhan'.title()
# Out:
# 'Hello Pragya Pradhan'

# %%
len('Hello pragya pradhan')
# Out:
# 20

# %%
chicago = pd.read_csv("chicago.csv").dropna(how ="all")
chicago["Department"] = chicago["Department"].astype("category")
chicago.tail(3)
# Out:
#                       Name           Position Title Department  \
# 32059    ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32060  ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32061  ZYSKOWSKI,  DARIUSZ  CHIEF DATA BASE ANALYST       DoIT
#
#       Employee Annual Salary
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00

# %%
"Hello World".replace("l","!")
# Out:
# 'He!!o Wor!d'

# %%
chicago["Department"] = chicago["Department"].str.replace("MGMNT", "MANAGEMENT")
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER  WATER MANAGEMENT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV  WATER MANAGEMENT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
chicago["Employee Annual Salary"] = chicago["Employee Annual Salary"].str.replace("$", "").astype(float)

# %%
chicago["Employee Annual Salary"].sum()
# Out:
# 2571506375.3600698

# %%
chicago["Employee Annual Salary"].nlargest()
# Out:
# 8184     300000.0
# 7954     216210.0
# 25532    202728.0
# 8924     197736.0
# 8042     197724.0
# Name: Employee Annual Salary, dtype: float64

# %%
chicago = pd.read_csv("chicago.csv").dropna(how ="all")
chicago["Department"] = chicago["Department"].astype("category")
chicago.tail(3)
# Out:
#                       Name           Position Title Department  \
# 32059    ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32060  ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32061  ZYSKOWSKI,  DARIUSZ  CHIEF DATA BASE ANALYST       DoIT
#
#       Employee Annual Salary
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00

# %%
mask = chicago["Position Title"].str.lower().str.contains("water")
chicago[mask]
# Out:
#                           Name                                 Position Title  \
# 0              AARON,  ELVIA J                               WATER RATE TAKER
# 554         ALUISE,  VINCENT G             FOREMAN OF WATER PIPE CONSTRUCTION
# 671            ANDER,  PERRY A                               WATER CHEMIST II
# 685        ANDERSON,  ANDREW J  DISTRICT SUPERINTENDENT OF WATER DISTRIBUTION
# 702          ANDERSON,  DONALD             FOREMAN OF WATER PIPE CONSTRUCTION
# 1054          ASHLEY,  KARMA T                               WATER CHEMIST II
# 1079         ATKINS,  JOANNA M                               WATER CHEMIST II
# 1181        AZEEM,  MOHAMMED A                               WATER CHEMIST II
# 1285            BAJIC,  JOHN A                          WATER METER MACHINIST
# 2400          BOLTON,  BRIAN E                               WATER RATE TAKER
# 2586           BOYCE,  ADNER L                               WATER CHEMIST II
# ...

# %%
chicago[chicago["Position Title"].str.lower().str.startswith("water")]
# Out:
#                           Name               Position Title   Department  \
# 0              AARON,  ELVIA J             WATER RATE TAKER  WATER MGMNT
# 671            ANDER,  PERRY A             WATER CHEMIST II  WATER MGMNT
# 1054          ASHLEY,  KARMA T             WATER CHEMIST II  WATER MGMNT
# 1079         ATKINS,  JOANNA M             WATER CHEMIST II  WATER MGMNT
# 1181        AZEEM,  MOHAMMED A             WATER CHEMIST II  WATER MGMNT
# 1285            BAJIC,  JOHN A        WATER METER MACHINIST  WATER MGMNT
# 2400          BOLTON,  BRIAN E             WATER RATE TAKER  WATER MGMNT
# 2586           BOYCE,  ADNER L             WATER CHEMIST II  WATER MGMNT
# 2745          BRANDYS,  DANIEL             WATER CHEMIST II  WATER MGMNT
# 3143          BROWN,  SHARON L             WATER RATE TAKER  WATER MGMNT
# 3246      BUCHANAN,  ANTHONY L             WATER CHEMIST II  WATER MGMNT
# 3456             BURT,  CARL S             WATER RATE TAKER  WATER MGMNT
# ...

# %%
mask = chicago["Position Title"].str.lower().str.endswith("er")
chicago[mask]
# Out:
#                         Name                     Position Title  \
# 0            AARON,  ELVIA J                   WATER RATE TAKER
# 1          AARON,  JEFFERY M                     POLICE OFFICER
# 2             AARON,  KARINA                     POLICE OFFICER
# 3        AARON,  KIMBERLEI R           CHIEF CONTRACT EXPEDITER
# 11          ABBATE,  TERRY M                     POLICE OFFICER
# 15           ABDALLAH,  ZAID                     POLICE OFFICER
# 16     ABDELHADI,  ABDALMAHD                     POLICE OFFICER
# 18        ABDELMAJEID,  AZIZ                     POLICE OFFICER
# 28         ABEJERO,  JASON V                     POLICE OFFICER
# 30     ABERCROMBIE,  TIMOTHY                 MOTOR TRUCK DRIVER
# 32           ABNEY,  PATRICK                     POLICE OFFICER
# 36         ABRAHAM,  NANCY A                     POLICE OFFICER
# 38       ABRAMS,  DANIELLE T                 SANITATION LABORER
# 39          ABRAMS,  HENRY L                     POLICE OFFICER
# ...

# %%
chicago = pd.read_csv("chicago.csv").dropna(how ="all")
chicago["Department"] = chicago["Department"].astype("category")
chicago.tail(3)
# Out:
#                       Name           Position Title Department  \
# 32059    ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32060  ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32061  ZYSKOWSKI,  DARIUSZ  CHIEF DATA BASE ANALYST       DoIT
#
#       Employee Annual Salary
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00

# %%
chicago["Name"].str.rstrip().str.lstrip()
# Out:
# 0                 AARON,  ELVIA J
# 1               AARON,  JEFFERY M
# 2                  AARON,  KARINA
# 3             AARON,  KIMBERLEI R
# 4             ABAD JR,  VICENTE M
# 5                 ABARCA,  ANABEL
# 6               ABARCA,  EMMANUEL
# 7               ABASCAL,  REECE E
# 8            ABBASI,  CHRISTOPHER
# 9           ABBATACOLA,  ROBERT J
# 10          ABBATEMARCO,  JAMES J
# 11               ABBATE,  TERRY M
# 12               ABBOTT,  BETTY L
# 13              ABBOTT,  LYNISE M
# 14         ABBRUZZESE,  WILLIAM J
# 15                ABDALLAH,  ZAID
# 16          ABDELHADI,  ABDALMAHD
# 17            ABDELLATIF,  AREF R
# 18             ABDELMAJEID,  AZIZ
# 19            ABDOLLAHZADEH,  ALI
# 20       ABDUL-KARIM,  MUHAMMAD A
# 21            ABDULLAH,  DANIEL N
# 22               ABDULLAH,  KEVIN
# 23           ABDULLAH,  LAKENYA N
# 24            ABDULLAH,  RASHAD J
# 25           ABDULSATTAR,  MUDHAR
# 26           ABDUL-SHAKUR,  TAHIR
# ...

# %%
chicago["Position Title"] = chicago["Position Title"].str.strip()
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
chicago = pd.read_csv("chicago.csv").dropna(how ="all")
chicago["Department"] = chicago["Department"].astype("category")
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
chicago.index = chicago.index.str.strip().str.title()
chicago.head(3)
# Out:
#                      Position Title   Department Employee Annual Salary
# Name
# Aaron,  Elvia J    WATER RATE TAKER  WATER MGMNT              $90744.00
# Aaron,  Jeffery M    POLICE OFFICER       POLICE              $84450.00
# Aaron,  Karina       POLICE OFFICER       POLICE              $84450.00

# %%
chicago.columns = chicago.columns.str.upper()
chicago.head()
# Out:
#                                POSITION TITLE        DEPARTMENT  \
# Name
# Aaron,  Elvia J              WATER RATE TAKER       WATER MGMNT
# Aaron,  Jeffery M              POLICE OFFICER            POLICE
# Aaron,  Karina                 POLICE OFFICER            POLICE
# Aaron,  Kimberlei R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# Abad Jr,  Vicente M         CIVIL ENGINEER IV       WATER MGMNT
#
#                     EMPLOYEE ANNUAL SALARY
# Name
# Aaron,  Elvia J                  $90744.00
# Aaron,  Jeffery M                $84450.00
# Aaron,  Karina                   $84450.00
# Aaron,  Kimberlei R              $89880.00
# Abad Jr,  Vicente M             $106836.00

# %%
"pragya nuchhe pradhan".split(" ")
# Out:
# ['pragya', 'nuchhe', 'pradhan']

# %%
chicago["Name"].str.split(",").str.get(1).str.title().value_counts()
# Out:
#   Michael J     270
#   Michael       165
#   Michael A     158
#   David         128
#   Robert J      120
#   Thomas J      120
#   Robert        107
#   Daniel J      102
#   John          100
#   John J         95
#   John M         95
#   Joseph         95
#   Daniel         95
#   Anthony        94
#   Patrick J      93
#   James M        85
#   James          82
#   John P         80
#   John A         78
#   Anthony J      75
#   Mark A         70
#   Michael P      66
#   David A        65
#   David J        65
#   Thomas         63
#   Michael R      63
#   Brian J        62
#   James P        62
#   Joseph A       60
#   Timothy J      60
#                ...
#   Tywan M         1
#   Jesus R         1
#   Randall V       1
#   Damon M         1
#   Holger A        1
#   Dean M          1
#   Rodney S        1
#   Fontaine        1
#   Kaylee L        1
#   Kittrell        1
#   Kisa K          1
#   Jesse K         1
#   Thelma G        1
#   Rey H           1
# ...

# %%
chicago["Position Title"].str.split(" ").str.get(2).value_counts()
# Out:
# (ASSIGNED            1037
# TRUCK                 918
# -                     830
# DRIVER                721
# OPERATOR              555
# AIDE-HOURLY           442
# OFFICER               347
# II                    310
# III                   253
# COUNSEL               218
# A                     177
# AIDE                  164
# ENTRY                 150
# CLERK                 149
# C                     147
# COORD                 144
# ARBITRATORS           139
# THE                   130
# TO                    119
# SPECIALIST            119
# OF                    116
# I                     114
# /                      96
# APPRENTICE             82
# ANALYST                78
# CHIEF                  75
# SUPVSR                 72
# REPRESENTATIVE         66
# IV                     63
# INSPECTOR              60
#                      ...
# PLANT                   1
# MAPS                    1
# PRESIDENT               1
# SIGN                    1
# ...

# %%
chicago = pd.read_csv("chicago.csv").dropna(how ="all")
chicago["Department"] = chicago["Department"].astype("category")
chicago.tail(3)
# Out:
#                       Name           Position Title Department  \
# 32059    ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32060  ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32061  ZYSKOWSKI,  DARIUSZ  CHIEF DATA BASE ANALYST       DoIT
#
#       Employee Annual Salary
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00

# %%
chicago["Name"].str.split(",").str.get(0).value_counts().head(3)
# Out:
# WILLIAMS    293
# JOHNSON     244
# SMITH       241
# Name: Name, dtype: int64

# %%
chicago["Name"].str.split(",").str.get(1).str.strip().str.split(" ").str.get(0).value_counts()
# Out:
# MICHAEL         1153
# JOHN             899
# JAMES            676
# ROBERT           622
# JOSEPH           537
# DAVID            506
# THOMAS           490
# DANIEL           472
# WILLIAM          397
# ANTHONY          385
# KEVIN            331
# BRIAN            320
# RICHARD          314
# MARK             310
# PATRICK          300
# MATTHEW          247
# TIMOTHY          243
# JOSE             224
# STEVEN           220
# CHRISTOPHER      217
# EDWARD           205
# PAUL             205
# KENNETH          201
# ERIC             170
# CHARLES          163
# JEFFREY          152
# GREGORY          150
# GEORGE           149
# MARY             147
# RONALD           147
#                 ...
# ALTHEA             1
# COLLETT            1
# BABABERTIUDE       1
# JANA               1
# EMERSON            1
# ASHFORD            1
# JLYNN              1
# ELADIO             1
# DESTRY             1
# MARAVIA            1
# FAROOQ             1
# ELIAZ              1
# ...

# %%
chicago = pd.read_csv("chicago.csv").dropna(how ="all")
chicago["Department"] = chicago["Department"].astype("category")
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
chicago [["First Name", "Last Name"]] = chicago["Name"].str.split(",", expand = True)

# %%
chicago.head(2)
# Out:
#                 Name    Position Title   Department Employee Annual Salary  \
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
#
#   First Name    Last Name
# 0      AARON      ELVIA J
# 1      AARON    JEFFERY M

# %%
chicago[["First Title", "Remanining Title"]] = chicago["Position Title"].str.split(" ", expand = True, n = 1)

# %%
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary  \
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00
#
#   First Name    Last Name First Title Remanining Title
# 0      AARON      ELVIA J       WATER       RATE TAKER
# 1      AARON    JEFFERY M      POLICE          OFFICER
# 2      AARON       KARINA      POLICE          OFFICER
